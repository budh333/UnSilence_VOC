# %%
import os
import csv
from tqdm import tqdm
import re
import pandas as pd
from typing import Dict

# %%
OUTPUT_DIR = os.path.join('..', '..', 'processed')
DATA_PATH = os.path.join('..', '..', '2021-national-archives-data-annotation-project', 'data')

# %%
def should_use_file(filepath) -> bool:
    # if file path is wrong for some reason, do not use it
    if not os.path.exists(filepath):
        return False

    file_stats = os.stat(filepath)

    # if file is empty, do not use it
    if file_stats.st_size == 0:
        return False

    return True

# %%
def get_filepaths(data_path, folders_to_ignore = []):
    result = []
    for folder_name in os.listdir(data_path):
        if folder_name in folders_to_ignore:
            continue

        folder_path = os.path.join(data_path, folder_name)

        if not os.path.isdir(folder_path): # it's a file
            if folder_path.endswith('.ann') and should_use_file(folder_path): # only work with .ann files
                result.append(os.path.splitext(folder_path)[0])

            continue

        sub_paths = get_filepaths(folder_path)
        if len(sub_paths) > 0:
            result.extend(sub_paths)

    return result

# %%
filepaths = get_filepaths(DATA_PATH, folders_to_ignore=['6847', 'Charles'])

# %%
def validate_line(line_text):
    '''
        Validate if a line is not marked as 'transcription error' or as a duplicated one.
        If any of those is true, this whole document must be skipped
    '''
    invalid = line_text.startswith('TranscriptionError') or line_text.startswith('DuplicatePage')
    return not invalid

# %%
class Constants():
    Empty = 'O'
    Beginning = 'B-'
    Inside = 'I-'

    MainEntityPrefix = 'T'
    SubEntityPrefix = 'A'

# %%
def process_annotation_file(filepath) -> Dict[int, Dict[str, str]]:
    result = []
    # Check for lines starting with TN, where N is a numeric value
    main_regex = re.compile(f'^[{Constants.MainEntityPrefix}][1-9]+')

    intervals = []

    with open(f'{filepath}.ann', 'r', encoding='utf-8') as file_handle:
        file_lines = file_handle.readlines()

        for file_line in file_lines:
            split_line = file_line.split('\t')
            line_key = split_line[0]

            if not main_regex.match(line_key): # Main entity type
                continue

            assert len(split_line) > 1, f'File line is invalid. Not enough tokens were found\n - Original split line: {split_line}\n - Filepath: "{filepath}"'

            # Skip documents that are not valid
            if not validate_line(split_line[1]):
                return None

            annotation = split_line[1].split()

            # some positions are doubled, e.g. '100 110; 111 120'
            positions = [[int(pos) for pos in x.strip().split()] for x in ' '.join(annotation[1:]).split(';')]

            if positions[0][0] > positions[-1][1]:
                print(filepath)
                print(positions)
            else:
                interval = pd.Interval(positions[0][0], positions[-1][1], closed='both')
                intervals.append((interval, line_key))


    for i, (interval_1, line_key_1) in enumerate(intervals):
        for k, (interval_2, line_key_2) in enumerate(intervals):
            if k <= i : continue
            if not interval_1.overlaps(interval_2): continue

            if interval_1.left < interval_2.left:
                if interval_2.right > interval_1.right and (interval_1, interval_2, line_key_1, line_key_2) not in result:
                    result.append((interval_1, interval_2, line_key_1, line_key_2))

            if interval_1.left > interval_2.left:
                if interval_2.right < interval_1.right and (interval_2, interval_1) not in result:
                    result.append((interval_2, interval_1, line_key_2, line_key_1))

    return result

def process_files(filepaths):
    result = {}
    for filepath in tqdm(filepaths, desc='Processing files'):
        overlapping_intervals = process_annotation_file(filepath)
        if overlapping_intervals is None or len(overlapping_intervals) == 0:
            continue

        result[filepath] = overlapping_intervals

    return result

# %%
intervals_by_file = process_files(filepaths)
# Out:
# Processing files:  35%|███▌      | 1012/2889 [00:00<00:00, 2997.16it/s]
# ..\..\2021-national-archives-data-annotation-project\data\Jonas\6860\NL-HaNA_1.04.02_6860_0303
# [[113, 129], [90, 108]]
# ..\..\2021-national-archives-data-annotation-project\data\Jonas\6860\NL-HaNA_1.04.02_6860_0394
# [[1002, 1028], [983, 986], [987, 1000]]
# ..\..\2021-national-archives-data-annotation-project\data\Roos\6857\NL-HaNA_1.04.02_6857_0173
# [[117, 134], [91, 116]]
# Processing files:  80%|███████▉  | 2297/2889 [00:00<00:00, 3933.65it/s]
# ..\..\2021-national-archives-data-annotation-project\data\Silja\6860\NL-HaNA_1.04.02_6860_0077
# [[106, 120], [86, 99]]
# ..\..\2021-national-archives-data-annotation-project\data\Silja\6860\NL-HaNA_1.04.02_6860_0077
# [[106, 120], [86, 99]]
# Processing files: 100%|██████████| 2889/2889 [00:00<00:00, 3684.80it/s]

# %%
for filepath, intervals in intervals_by_file.items():
    print(f'\nFilepath: "{filepath}"')
    for interval_1, interval_2, line_key_1, line_key_2 in intervals:
        print(f'  - {line_key_1:3s} <{interval_1.left:4d}, {interval_1.right:4d}> overlaps {line_key_2:3s} <{interval_2.left:4d}, {interval_2.right:4d}>')
# Out:
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Bert\6848\NL-HaNA_1.04.02_6848_0007"
#   - T34 <1603, 1616> overlaps T35 <1612, 1617>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Bert\6857\NL-HaNA_1.04.02_6857_0011"
#   - T11 < 316,  343> overlaps T12 < 335,  344>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6848\NL-HaNA_1.04.02_6848_0088"
#   - T20 <1627, 1648> overlaps T21 <1642, 1649>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6848\NL-HaNA_1.04.02_6848_0100"
#   - T28 < 621,  650> overlaps T8  < 622,  675>
#   - T24 <1169, 1200> overlaps T25 <1178, 1201>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6848\NL-HaNA_1.04.02_6848_0109"
#   - T8  < 991, 1010> overlaps T24 <1002, 1011>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6857\NL-HaNA_1.04.02_6857_0121"
#   - T11 < 551,  573> overlaps T12 < 556,  574>
#   - T13 < 878,  901> overlaps T14 < 889,  902>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6857\NL-HaNA_1.04.02_6857_0153"
#   - T13 < 930,  946> overlaps T14 < 941,  947>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6860\NL-HaNA_1.04.02_6860_0110"
#   - T18 <1224, 1238> overlaps T19 <1225, 1252>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6860\NL-HaNA_1.04.02_6860_0202"
#   - T6  < 414,  429> overlaps T5  < 415,  442>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6860\NL-HaNA_1.04.02_6860_0219"
#   - T1  <  23,   67> overlaps T2  <  40,   68>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6869\NL-HaNA_1.04.02_6869_0183"
#   - T10 < 341,  371> overlaps T11 < 351,  372>
#   - T10 < 341,  371> overlaps T14 < 351,  372>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6869\NL-HaNA_1.04.02_6869_0184"
#   - T46 <1614, 1649> overlaps T49 <1633, 1650>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6869\NL-HaNA_1.04.02_6869_0188"
#   - T19 < 766,  812> overlaps T20 < 796,  813>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0139"
#   - T7  < 193,  225> overlaps T8  < 204,  226>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0148"
#   - T7  < 525,  617> overlaps T9  < 601,  618>
#   - T7  < 525,  617> overlaps T10 < 611,  618>
#   - T8  < 525,  617> overlaps T9  < 601,  618>
#   - T8  < 525,  617> overlaps T10 < 611,  618>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0190"
#   - T3  <1319, 1355> overlaps T4  <1336, 1358>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0506"
#   - T5  < 848,  871> overlaps T7  < 865,  872>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0507"
#   - T7  < 523,  542> overlaps T8  < 529,  543>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Emma\6870\NL-HaNA_1.04.02_6870_0510"
#   - T22 <1262, 1286> overlaps T23 <1273, 1287>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Jonas\6860\NL-HaNA_1.04.02_6860_0381"
#   - T8  < 448,  474> overlaps T9  < 470,  483>
#   - T8  < 448,  474> overlaps T10 < 470,  483>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6860\NL-HaNA_1.04.02_6860_0468"
#   - T13 <1017, 1036> overlaps T14 <1021, 1037>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6863\txtNL-HaNA_1.04.02_6863_0367"
#   - T1  < 122,  179> overlaps T2  < 170,  180>
#   - T1  < 122,  179> overlaps T3  < 170,  180>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6863\txtNL-HaNA_1.04.02_6863_0396"
#   - T27 <1624, 1648> overlaps T28 <1629, 1649>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6865\NL-HaNA_1.04.02_6865_0050"
#   - T5  < 830,  854> overlaps T6  < 835,  855>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6870\NL-HaNA_1.04.02_6870_0331"
#   - T6  < 536,  560> overlaps T7  < 543,  561>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6872\NL-HaNA_1.04.02_6872_0250"
#   - T5  < 638,  666> overlaps T6  < 651,  667>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6878\NL-HaNA_1.04.02_6878_0151"
#   - T2  <1134, 1199> overlaps T3  <1189, 1211>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Roos\6878\NL-HaNA_1.04.02_6878_0165"
#   - T8  < 231,  246> overlaps T7  < 239,  262>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Silja\6848\NL-HaNA_1.04.02_6848_0050"
#   - T22 <1348, 1390> overlaps T23 <1367, 1391>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Silja\6848\NL-HaNA_1.04.02_6848_0151"
#   - T1  < 458,  487> overlaps T2  < 468,  488>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6853\NL-HaNA_1.04.02_6853_0036"
#   - T1  < 145,  167> overlaps T2  < 148,  168>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6857\NL-HaNA_1.04.02_6857_0239"
#   - T42 <1344, 1357> overlaps T43 <1348, 1358>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6860\NL-HaNA_1.04.02_6860_0149"
#   - T7  < 469,  480> overlaps T8  < 473,  481>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6860\NL-HaNA_1.04.02_6860_0154"
#   - T22 < 924,  945> overlaps T23 < 932,  946>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6860\NL-HaNA_1.04.02_6860_0157"
#   - T15 <1575, 1594> overlaps T16 <1586, 1595>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6863\txtNL-HaNA_1.04.02_6863_0403"
#   - T32 <1870, 1881> overlaps T33 <1879, 1882>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6863\txtNL-HaNA_1.04.02_6863_0410"
#   - T1  <  32,   47> overlaps T2  <  37,   48>
#   - T38 < 490,  500> overlaps T39 < 495,  501>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6863\txtNL-HaNA_1.04.02_6863_0433"
#   - T11 < 774,  791> overlaps T12 < 779,  792>
#   - T15 <1645, 1676> overlaps T16 <1665, 1677>
#   - T19 <1645, 1676> overlaps T16 <1665, 1677>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6863\txtNL-HaNA_1.04.02_6863_0448"
#   - T9  < 526,  536> overlaps T10 < 529,  537>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6872\NL-HaNA_1.04.02_6872_0104"
#   - T4  < 311,  321> overlaps T6  < 317,  322>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6872\NL-HaNA_1.04.02_6872_0147"
#   - T4  <  80,  104> overlaps T5  <  91,  105>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6891\NL-HaNA_1.04.02_6891_0254"
#   - T5  < 323,  342> overlaps T6  < 329,  343>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6891\NL-HaNA_1.04.02_6891_0257"
#   - T3  < 578,  597> overlaps T4  < 583,  598>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6891\NL-HaNA_1.04.02_6891_0261"
#   - T20 < 608,  652> overlaps T21 < 628,  653>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6891\NL-HaNA_1.04.02_6891_0269"
#   - T8  < 412,  422> overlaps T9  < 422,  435>
#   - T10 < 412,  422> overlaps T9  < 422,  435>
#
# Filepath: "..\..\2021-national-archives-data-annotation-project\data\Yolien\6895\NL-HaNA_1.04.02_6895_0016"
#   - T14 <1229, 1253> overlaps T15 <1242, 1254>
